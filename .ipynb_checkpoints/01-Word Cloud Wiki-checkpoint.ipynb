# %%
# %matplotlib inline

# %%
# %run wiki_cloud.py

# %%
# Create WordClound from Guns N Roses Wikipedia page.

create_wordcloud(get_wiki("guns n roses"))

# %%
# Create WordCloud from Beastie Boys Wikipedia page.

create_wordcloud(get_wiki("beastie boys"))

# %%
# Create WordCloud from Led Zeppelin Wikipedia page.

create_wordcloud(get_wiki("led zeppelin"))
