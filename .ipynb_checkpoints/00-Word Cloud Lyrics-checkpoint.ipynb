# %%
# Standard imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# WordCloud imports

import os
from os import path
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# Make data directory
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Create mask for cloud shape:
mask = np.array(Image.open(path.join(d, "cloud.png")))

# Create Stopwords:
stopwords = set(STOPWORDS)

# %%
# Read the whole text file of November Rain lyrics by Guns N Roses.
text = open(path.join(d, 'november.txt')).read()

# Create WordClound with max_font_size:
wordcloud = WordCloud(max_font_size=40, mask=mask, background_color="black", stopwords=stopwords).generate(text)
plt.figure(figsize=(12, 12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Read the text file of Stairway to Heaven lyrics by Led Zeppelin.

text = open(path.join(d, 'stairway.txt')).read()

# Create WordClound with max_font_size:
wordcloud = WordCloud(max_font_size=40, mask=mask, background_color="black", stopwords=stopwords).generate(text)
plt.figure(figsize=(12,12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Read the whole text file of No Sleep Till Brooklyn lyrics by Beastie Boys.

text = open(path.join(d, 'brooklyn.txt')).read()

# Create WordClound with max_font_size:
wordcloud = WordCloud(max_font_size=40, mask=mask, background_color="black", stopwords=stopwords).generate(text)
plt.figure(figsize=(12,12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
